# %%
# Import necessary packages here, e.g.
import numpy as np                 # for numerical operations
import matplotlib.pyplot as plt    # for plotting
import cartopy.crs as ccrs         # for displaying global map
import cartopy.feature as cfeature # for displaying global map
import pandas as pd                # for interpereting data

# Add other packages as needed, for example:
# import pandas as pd            # for data manipulation

# %% [markdown]
# # Volcanoes: VEI vs. Last Eruption
# *(Replace "Descriptive Project Title" above with the actual title of your project)*
#
# **Samuel Satushek**
# *(Replace "Your Name" with your full name)*
#
# OCEAN 215 Final Project
# Autumn 2024

# %% [markdown]
# ## Introduction
#
# <!-- Include your motivation and any background information needed to understand your research question and data analysis. Clearly state your research question and hypothesis. -->
#
# *(Write 1–2 paragraphs below)*
#
# There are many different types of volcanoes around the world, with different shapes, sizes, eruption styles, and more. My project dives into how frequently volcanoes with different eruption styles erupt. The VEI scale measures a volcano's explosiveness, with VEI 0 being not explosive (like Hawaii) and VEI 8 being very explosive (like Yellowstone). The question I want to answer is how often do volcanoes with a low VEI erupt in comparison to volcanoes with a high VEI? I hypothesize that volcanoes with a higher VEI take more time between eruptions than volcanoes with a lower VEI.

# %% [markdown]
# ## Data sources:
# <!-- List each data source used in your project. For each dataset, include:
#      - Where you accessed it from
#      - Date you accessed/downloaded it
#      - Data collection process
#      - Relevant variables (including unit)
#      - Spatial and temporal coverage and resolution
#      - Description of any obstacles or challenges you faced in obtaining the dataset
#      - URL to the dataset if available -->
#
# - volcano-events-2024-11-14_16-54-14_-0800.tsv
#   - Downloaded from noaa.gov on  *e.g., 2024-11-15*.
#   - Data collection process: Data collected by many different methods, including (but not limited to) cameras, infrared technology, and geologic sampling.
#   - Relevant variables included:
#     - VEI of most recent eruption (scale of 0-8)
#     -Date of most recent eruption (measured in years)
#   - Obstacles to data access: no major obstacles, but I was originally going to focus only on the Cascadia Subduction Zone, but there were not enough eruptions to make my dataset large enough.
#   - URL to dataset: https://www.ngdc.noaa.gov/hazel/view/hazards/volcano/event-data?minYear=1000
# <br>

# %% [markdown]
# ## 1. Volcanoes colored by VEI
# *(Replace "Section 1 Title" with something meaningful, e.g., "Analyzing Seasonal Temperature Trends")*
#
# <!-- In this cell, introduction the data set(s) you are working with, specify which aspect of your research question this section addresses, and describe the figure you will produce. -->
#
# This figure will consist of a map featuring all volcanoes that have erupted in the last 1,000 years, color coded by their VEI. This map is meant to compare the abundance of explosive vs. non explosive volcanic eruptions.

# %%
# load data file(s)
data = pd.read_csv("volcano-events-2024-11-14_16-54-14_-0800.tsv", sep='\t')
display(data)
# as part of commenting your code throughout this section, discuss any problems you encountered and how you solved them
# Out:
#     Search Parameters    Year    Mo    Dy     Tsu       Eq
# 0    ["Year >= 1000"]     NaN   NaN   NaN     NaN      NaN  \
# 1                 NaN  1050.0   NaN   NaN  3102.0      NaN
# 2                 NaN  1104.0  10.0  15.0     NaN      NaN
# 3                 NaN  1151.0   NaN   NaN     NaN      NaN
# 4                 NaN  1158.0   1.0  19.0     NaN      NaN
# ..                ...     ...   ...   ...     ...      ...
# 832               NaN  2024.0   4.0  20.0     NaN      NaN
# 833               NaN  2024.0   5.0  11.0     NaN      NaN
# 834               NaN  2024.0   6.0   3.0     NaN      NaN
# 835               NaN  2024.0   8.0  17.0  5923.0  10744.0
# 836               NaN  2024.0  11.0   3.0     NaN      NaN
#
#                       Name         Location      Country  Latitude  ...
# 0                      NaN              NaN          NaN       NaN  ...  \
# 1                Santorini           Greece       Greece    36.404  ...
# ...

# %%
# perform data cleaning steps

# %%
# perform data analysis
lat = data["Latitude"]
lon = data["Longitude"]

# %%
#The following comment lines is the code I was originally using that gave me errors. I kept it just in case.


# make and display the first figure
#fig = plt.figure(figsize=(12, 5))
#ax = fig.add_subplot(projection = ccrs.Robinson())

#ax.coastlines(resolution='110m', color='black')
#ax.add_feature(cfeature.LAND, color='lemonchiffon')

#p = ax.scatter(lon, lat, transform=ccrs.PlateCarree())

#g2=ax.gridlines(crs=ccrs.PlateCarree(), color='black')
#g2.bottom_labels=True
#g2.left_labels=True


#plt.show()


#Code that actually worked:
volcanoes = pd.DataFrame(data)

# Set up the figure
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(projection=ccrs.Robinson())

# Add coastlines and land features
ax.coastlines(resolution='110m', color='black')
ax.add_feature(cfeature.LAND, color='lemonchiffon')

# Plot volcanoes, coloring points by VEI
sc = ax.scatter(
    volcanoes['Longitude'],
    volcanoes['Latitude'],
    c=volcanoes['VEI'],  # Color based on VEI
    cmap='magma',         # Choose a color map
    s=50,                # Marker size
    transform=ccrs.PlateCarree()
)

# Add a colorbar
cb = plt.colorbar(sc, ax=ax, orientation='horizontal', pad=0.05)
cb.set_label('Volcanic Explosivity Index (VEI)')

# Add gridlines
g2 = ax.gridlines(crs=ccrs.PlateCarree(), color='black', draw_labels=True)
g2.bottom_labels = True
g2.left_labels = True

# Show the plot
plt.show()

# %% [markdown]
# <!-- Describe how this figure helps address your research question. What patterns or insights can you observe? -->
# **Figure 1 Caption:** The vast majority of dots on this map have a darker color, indicating that most eruptions in the last 1,000 years had a lower VEI, which helps to support my hypothesis that explosive eruptions are not as common as effusive (non explosive) eruptions.

# %% [markdown]
# ## 2. Volcanoes colored by most recent eruption date
#
# <!-- In the introduction below, specify the data set(s) you are working with in this section, which aspect of your research question this section addresses, and the figure you will produce -->
#
# This map allows you to see what year each volcano erupted, and when compared to the map above, you can also see the VEI of that eruption. This can show you the year each volcano erupted, AND what its VEI was.

# %%
# if a new dataset, load data and perform data cleaning steps
# otherwise, continue to data analysis and figure creation

# %%
# perform data analysis
lat = data["Latitude"]
lon = data["Longitude"]

# %%
# make and display figure

volcanoes = pd.DataFrame(data)

# Set up the figure
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(projection=ccrs.Robinson())

# Add coastlines and land features
ax.coastlines(resolution='110m', color='black')
ax.add_feature(cfeature.LAND, color='lemonchiffon')

# Plot volcanoes, coloring points by VEI
sc = ax.scatter(
    volcanoes['Longitude'],
    volcanoes['Latitude'],
    c=volcanoes['Year'],  # Color based on VEI
    cmap='viridis',         # Choose a color map
    s=50,                # Marker size
    transform=ccrs.PlateCarree()
)

# Add a colorbar
cb = plt.colorbar(sc, ax=ax, orientation='horizontal', pad=0.05)
cb.set_label('Last Eruption Year')

# Add gridlines
g2 = ax.gridlines(crs=ccrs.PlateCarree(), color='black', draw_labels=True)
g2.bottom_labels = True
g2.left_labels = True

# Show the plot
plt.show()

# %% [markdown]
# <!-- Describe how this figure helps address your research question. What patterns or insights can you observe? -->
# **Figure 2 Caption:** When comparing the two maps, you can see that generally, volcanoes with a higher VEI erupted longer ago than volcanoes with a lower VEI, farther supporting my hypothesis that higher VEI eruptions don't occur as frequently.

# %% [markdown]
# ## 3. Eruption date vs. VEI on a histogram
#
# <!-- In the introduction below, specify the data set(s) you are working with in this section, which aspect of your research question this section addresses, and the figure you will produce -->
#
# One of my two maps above showed the VEI of each volcanic eruption in the last 1,000 years, while the other showed the eruption date. These plots will merge the two datasets to show how many eruptions at each VEI level occurred, giving you an idea of the low:high VEI ratio, while also factoring in how long ago they happened.

# %%
# if a new dataset, load data and perform data cleaning steps
# otherwise, continue to data analysis and figure creation

# %%
# perform data analysis
lat = data["Latitude"]
lon = data["Longitude"]

# %%
# make and display figure
fig, axs = plt.subplots()

#time vs. cellular carbon
x = volcanoes['Year']
y = volcanoes['VEI']

#plot
axs.scatter(x, y, marker = '.', color = 'orangered')

#labels
axs.set_xlabel("Year", fontsize = 15)
axs.set_ylabel("VEI", fontsize = 15)
axs.set_title("VEI vs. last eruption")

#Histogram of recent eruptions
plt.figure()
plt.hist(volcanoes['Year'], color = 'darkturquoise')

#Labels
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Number of volcanoes", fontsize = 15)
plt.title("Distribution of eruption dates")

#Historgram of eruption VEI indicies
plt.figure()
plt.hist(volcanoes['VEI'], color = 'yellowgreen')

#Labels
plt.xlabel("VEI", fontsize = 15)
plt.ylabel("Number of volcanoes", fontsize = 15)
plt.title("Distribution of VEI indicies")
# Out:
# Text(0.5, 1.0, 'Distribution of VEI indicies')

# %% [markdown]
# <!-- Describe how this figure helps address your research question. What patterns or insights can you observe? -->
# **Figure 3 Caption:** The first plot shows each volcano's last eruption year and VEI. The layout of dots indicates that the number of volcanoes decreases as each VEI index increases, and the amount of time since the last eruption increases. This is indicated by the lower VEI indicies having more dots than the higher ones. Note that the VEI scale goes to 8, but there has not been a single VEI 8 eruption in the last 1,000 years, so the chart omits it.
# My claim is further supported by the two bar graphs. The blue graph shows that most volcanoes have erupted recently (last 200 years), and the distribution decreases as you go back in time. The green graph shows the VEI of each volcano, indicating that the most common VEI is 2, while it is very uncommon for a VEI to exceed 4.

# %% [markdown]
# ## Discussion
# **Interpretation of Results:**  *(Write ~1 paragraph below)*
# My results support my hypothesis that volcanoes with a higher VEI take longer to erupt, and that the VEI of most volcanoes is on the lower end of the scale. One thing I learned that surprised me is that the majority of volcanoes around the world have erupted within the last 200 years. I was expecting my bar graphs to peak at around the year 1500 instead.
#
# **Limitations and Future Work:**  *(Write ~1 paragraph below)*
# The biggest limitation to this project is that this data only accounts for each volcano's most recent eruption. If I could analyze all eruptions, my data would be more accurate because I could see any unexpected anomalies, such as a VEI 6 volcano erupting in 1100 and again in 1300, for example. With my current data, I would only see the 1300 eruption. To better my data in the future, I could include data from multiple eruptions by the same volcano.

# %% [markdown]
# ## References
#
# *Cite all papers, websites, or other resources you referenced in your project. Use a consistent citation style (e.g., APA, MLA, Chicago).*
#
#
# 3. **National Oceanic and Atmospheric Administration.** (11-15-2024). *Volcano Locations*. https://www.ngdc.noaa.gov/hazel/view/hazards/volcano/event-data?minYear=1000
#
# *This is the only source I used.*
